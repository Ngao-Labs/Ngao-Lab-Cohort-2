# %% [markdown]
# # for Loops
#
# A <code>for</code> loop acts as an iterator in Python; it goes through items that are in a *sequence* or any other iterable item. Objects that we've learned about that we can iterate over include strings, lists, tuples, and even built-in iterables for dictionaries, such as keys or values.
#
# We've already seen the <code>for</code> statement a little bit in past lectures but now let's formalize our understanding.
#
# Here's the general format for a <code>for</code> loop in Python:
#
#     for item in object:
#         statements to do stuff

# %% [markdown]
# The variable name used for the item is completely up to the coder, so use your best judgment for choosing a name that makes sense and you will be able to understand when revisiting your code. This item name can then be referenced inside your loop, for example if you wanted to use <code>if</code> statements to perform checks.
#
# Let's go ahead and work through several example of <code>for</code> loops using a variety of data object types. We'll start simple and build more complexity later on.

# %%
day="Teusday" # iterate/go through the character/letter
my_list=[1,2,3,4,5] # go through the item
numbers=(1,2,3,4) # through the items
person={"name":"john", "age":20} # Go through items/ keys/values

# %%
for num in my_list:
    print(num**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
for num in numbers:
    print(num)
# Out:
# 1
# 2
# 3
# 4

# %%
for item in person:
    print(item+" "+ str(person[item]))
# Out:
# name john
# age 20

# %%
for letter in day:
    print(letter)
# Out:
# T
# e
# u
# s
# d
# a
# y

# %%
even=[]
for num in my_list:
    if(num % 2 ==0):
        even.append(num)

# %%
even
# Out:
# [2, 4]

# %%
list2=[(2,4),(3,4),(4,5)] # A list of tuples

for item in list2:
    for x in item:
        print(x)
        break

# Tuple unpacking way
for a,b in list2:
    print(a)
# Out:
# 2
# 3
# 4
# 2
# 3
# 4

# %%
person
# Out:
# {'name': 'john', 'age': 20}

# %%
for item in person.items():
    print(item)
# Out:
# ('name', 'john')
# ('age', 20)

# %%
# Print the keys
person.keys()

person.values()


for key,val in person.items():
    # F-String Literals (whenever we want to reference an external variable in a string)
    # str(val) converts integer to string

    print("key "+ key + " and value "+ str(val))
    print(f"key: {key} and value: {val}")
# Out:
# key name and value john
# key: name and value: john
# key age and value 20
# key: age and value: 20

# %%
help(person.items)
# Out:
# Help on built-in function items:
#
# items(...) method of builtins.dict instance
#     D.items() -> a set-like object providing a view on D's items

# %%
# ()- calling a method
# : when separating the control flow header and body - now the body starts here(body - where we write the logic)
# comma(,) - separating items
# . - Dot notation - access the methods of a datatype/a defined class


person.items()
# Out:
# dict_items([('name', 'john'), ('age', 20)])

# %%
#() Parenthesis - Used to call a method/fuction / Create a tuple/ create a Set
# [] Brackets - Create a List / Accessing a valua in a dict bracket notation ( person['age'])
# {} - F-string - refering to an external variable / Creating a dictionary
