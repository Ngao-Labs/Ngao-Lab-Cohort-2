# %% [markdown]
# # Lists
#
# Earlier when discussing strings we introduced the concept of a *sequence* in Python. Lists can be thought of the most general version of a *sequence* in Python. Unlike strings, they are mutable, meaning the elements inside a list can be changed!
#
# In this section we will learn about:
#
#     1.) Creating lists
#     2.) Indexing and Slicing Lists
#     3.) Basic List Methods
#     4.) Nesting Lists
#     5.) Introduction to List Comprehensions
#
# Lists are constructed with brackets [] and commas separating every element in the list.

# %%
# [] bracket notation is the literal of list

trainees=[]
print(type(trainees))
# Out:
# <class 'list'>

# %%
# List are mutable

# add we use append() method

trainees.append("Pauline")
trainees.append("Frankline")
trainees.append("Amal")
trainees.append("Jacqy")
trainees.append("Mordecai")

# mutate- change/replace

trainees[0]="Jane"
trainees
# Out:
# ['Jane', 'Frankline', 'Amal', 'Jacqy', 'Mordecai']

# %% [markdown]
#  append
#  pop
#  reverse
#  sort
#  mutability
#  indexing & slicing

# %%
#trainees.pop(3) -remote item at index 3
trainees.sort()
trainees.reverse()
print(trainees)
print(trainees[:2])
print(trainees[2:])
print(trainees[2:4])
print(trainees[-1:])
# Out:
# ['Mordecai', 'Jane', 'Jacqy', 'Frankline', 'Amal']
# ['Mordecai', 'Jane']
# ['Jacqy', 'Frankline', 'Amal']
# ['Jacqy', 'Frankline']
# ['Amal']
