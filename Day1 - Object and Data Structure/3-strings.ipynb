# %% [markdown]
# Strings are used in Python to record text information, such as names. Strings in Python are actually a *sequence*, which basically means Python keeps track of every element in the string as a sequence. For example, Python understands the string "hello' to be a sequence of letters in a specific order. This means we will be able to use indexing to grab particular letters (like the first letter, or the last letter).
#
# This idea of a sequence is an important one in Python and we will touch upon it later on in the future.
#
# In this lecture we'll learn about the following:
#
#     1.) Creating Strings
#     2.) Printing Strings
#     3.) String Indexing and Slicing
#     4.) String Properties
#     5.) String Methods
#     6.) Print Formatting

# %% [markdown]
# ## Creating a String
# To create a string in Python you need to use either single quotes or double quotes. For example:

# %%
first_name = 'John'
second_name = "Doe"
# string literals

sentence = " I'm learning Python "

first_name
# Out:
# 'John'

# %% [markdown]
# ## Printing a String
#
# Using  notebook with just a string in a cell will automatically output strings, but the correct way to display strings in your output is by using a print function.

# %%
print(first_name)
# Out:
# John

# %% [markdown]
# ## String Indexing
# We know strings are a sequence, which means Python can use indexes to call parts of the sequence. Let's learn how this works.
#
# In Python, we use brackets <code>[]</code> after an object to call its index. We should also note that indexing starts at 0 for Python. Let's create a new object called <code>s</code> and then walk through a few examples of indexing.

# %%
greeting= "Hello There"
# iterable -index to get a value/ char / part of a string
# with index we start at 0 
# When we go to the right we use positive numbers / when we go to the left we use negative numbers
greeting[5]
# Out:
# ' '

# %% [markdown]
# We can use a <code>:</code> to perform *slicing* which grabs everything up to a designated point. For example:

# %%
# []
# starting point - int
# ending point ( is not included) - int
# step - skip some parts/intervals

greeting[0:] # from index Zero to the end
greeting[:5] # from index Zero upto the defined index(5)
greeting[6:11] # Selecting a Part

greeting[0:11:2] # skip one char in between

## Negative

greeting[-1] # Last Character
greeting[-1:] # Last Character

greeting[:-1] # grab everything but the last

greeting[::]# get me the whole string

greeting[::-1]# Reversing a string
# Out:
# 'erehT olleH'

# %% [markdown]
# ## String Properties
# Its important to note that strings have an important property known as immutability. This means that once a string is created, the elements within it can not be changed or replaced.

# %%
name ="Joe"
# I want to convert Joe to be Joy
# Concatenation & Indexing

#name[-1]="y" - STRINGS ARE IMMUTABLE SO YOU CANT REPLACE A CHARACTER
# Variable reassignment
# Concatenation - Combining two string 

name = name[:2] +"y"
name
123 + 4 # + with two numbers its addition

'123'+'4' # + with strings its combining them together (concatenation)

# %% [markdown]
# ## Basic Built-in String methods
#
# Objects in Python usually have built-in methods. These methods are functions inside the object (we will learn about these in much more depth later) that can perform actions or commands on the object itself.
#
# We call methods with a period and then the method name. Methods are in the form:
#
# object.method(parameters)
#
# Where parameters are extra arguments we can pass into the method. Don't worry if the details don't make 100% sense right now. Later on we will be creating our own objects and functions!
#
# Here are some examples of built-in methods in strings:,

# %%
len(greeting) # length - count all character in a string

# ()- parenthesis - calling a method
#lower() - to lowercase
print(greeting)
greeting.lower()


# upper - to Uppercase

print(greeting.upper())
# Out:
# Hello There
# HELLO THERE

# %% [markdown]
# # Formatting string
#
# `.format()` method
#
#
# Formatted String Literals (f-strings)

# %%
name= "Mordecai"
age=20
# Concatenation
sentence = name + " said 'it was a Mistake' "
print(sentence)

# format Method
sentence = "{} said 'it was a Mistake'{}".format(name,"fhdc")
print(sentence)
# F-string
sentence = f"{name} said 'it was a Mistake' {age}"

print(sentence)
# Out:
# Mordecai said 'it was a Mistake'
# Mordecai said 'it was a Mistake'fhdc
# Mordecai said 'it was a Mistake' 20

# %%
# Research on Split/Join
